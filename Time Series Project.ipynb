# %%
import pandas as pd
import numpy as np

# %%
from skimpy import clean_columns

# %%
df = pd.read_csv("LakeData.csv", low_memory = False)

# %%
df2 = pd.read_csv("Lake physical data.csv", low_memory = False)

# %%
df2.rename(columns={'Lake': 'lake_name'}, inplace=True)

# %%
clean_df2 = clean_columns(df2)
# Out:
# 4 column names have been cleaned

# %%
clean_df2.rename(columns={'lake': 'lake_name'}, inplace=True)

# %%
clean_df = clean_columns(df)
# Out:
# 52 column names have been cleaned

# %%
from datetime import datetime
clean_df['date'] = pd.to_datetime(clean_df['date'], format='%m/%d/%Y')
clean_df
# Out:
#         lake_name site_type       id_#       date   time   pw    w  \
# 0      Beaver Dam      Open  21221BEA2 2021-08-09  15:40    S    S
# 1      Beaver Dam      Open  18190BEA2 2018-07-09  15:00    S    S
# 2      Beaver Dam      Open  18204BEA2 2018-07-23  15:15    R    R
# 3      Beaver Dam      Open  18211BEA2 2018-07-31  15:00    O    O
# 4      Beaver Dam      Open  18218BEA2 2018-08-06  14:45    S    O
# ...           ...       ...        ...        ...    ...  ...  ...
# 24215         NaN       NaN        NaN        NaT    NaN  NaN  NaN
# 24216         NaN       NaN        NaN        NaT    NaN  NaN  NaN
# 24217         NaN       NaN        NaN        NaT    NaN  NaN  NaN
# 24218         NaN       NaN        NaN        NaT    NaN  NaN  NaN
# 24219  Beaver Dam      Open  16253BEA2 2016-09-09  13:37    R    O
#
#        total_depth_m secchi_depth  depth_m  ...  ss   f  \
# 0               18.5          2.5      0.0  ... NaN NaN
# 1               18.0          3.0      0.0  ... NaN NaN
# 2               19.0          5.8      0.0  ... NaN NaN
# 3               18.6          4.4      0.0  ... NaN NaN
# 4               18.8          4.4      0.0  ... NaN NaN
# ...              ...          ...      ...  ...  ..  ..
# 24215            NaN          NaN      NaN  ... NaN NaN
# 24216            NaN          NaN      NaN  ... NaN NaN
# 24217            NaN          NaN      NaN  ... NaN NaN
# 24218            NaN          NaN      NaN  ... NaN NaN
# 24219           18.4          4.6      NaN  ... NaN NaN
#
#                                                    notes  quanta_#  \
# 0                                                    NaN       NaN
# 1      AQUATIC WEED CONTROL SPRAYED IN THE MORNING (7...       NaN
# 2                                                    NaN       NaN
# 3                                                    NaN       NaN
# 4                                                    NaN       NaN
# ...                                                  ...       ...
# 24215                                                NaN       NaN
# 24216                                                NaN       NaN
# 24217                                                NaN       NaN
# 24218                                                NaN       NaN
# 24219                                                NaN       NaN
#
#        weather_meter_#  fluorometer_# aquafluor_# van_dorn_# unnamed_50  \
# 0                  NaN            NaN         NaN        NaN        NaN
# 1                  NaN            NaN         NaN        NaN        NaN
# 2                  NaN            NaN         NaN        NaN        NaN
# 3                  NaN            NaN         NaN        NaN        NaN
# 4                  NaN            NaN         NaN        NaN        NaN
# ...                ...            ...         ...        ...        ...
# 24215              NaN            NaN         NaN        NaN        NaN
# 24216              NaN            NaN         NaN        NaN        NaN
# 24217              NaN            NaN         NaN        NaN        NaN
# 24218              NaN            NaN         NaN        NaN        NaN
# 24219              NaN            NaN         NaN        NaN        NaN
#
#       unnamed_51
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 24215        NaN
# 24216        NaN
# 24217        NaN
# 24218        NaN
# 24219        NaN
#
# [24220 rows x 52 columns]

# %%
cdf = clean_df[["lake_name",'date','mc_ppb', 'do_mg_l', 'water_temp_cel_s']]
cdf = cdf.dropna()
cdf.head()
# Out:
#     lake_name       date  mc_ppb  do_mg_l  water_temp_cel_s
# 1  Beaver Dam 2018-07-09   0.075     8.75             28.83
# 2  Beaver Dam 2018-07-23   0.075     7.27             25.21
# 3  Beaver Dam 2018-07-31   0.075     8.55             25.10
# 4  Beaver Dam 2018-08-06   0.075     9.30             28.77
# 5  Beaver Dam 2020-06-01   0.075    13.83             22.40

# %%
cdf.index = pd.to_datetime(cdf['date'])

# %%
cdf = cdf.drop(['date'], axis=1)

# %%
cdf
# Out:
#                lake_name  mc_ppb  do_mg_l  water_temp_cel_s
# date
# 2018-07-09    Beaver Dam   0.075     8.75             28.83
# 2018-07-23    Beaver Dam   0.075     7.27             25.21
# 2018-07-31    Beaver Dam   0.075     8.55             25.10
# 2018-08-06    Beaver Dam   0.075     9.30             28.77
# 2020-06-01    Beaver Dam   0.075    13.83             22.40
# ...                  ...     ...      ...               ...
# 2010-08-17        Winona   0.075     7.36             27.00
# 2010-09-22        Winona   0.075     9.40             21.30
# 2012-09-10        Winona   0.075     7.61             24.40
# 2016-07-20        Winona   0.075     9.44             27.58
# 2012-09-13  Yellow Creek   0.607     7.56             23.60
#
# [1269 rows x 4 columns]

# %%
from tslearn.clustering import TimeSeriesKMeans
model = TimeSeriesKMeans(n_clusters=3, metric="dtw", max_iter=10)
model.fit(cdf)
#model.predict(cdf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [62], line 3
#       1 from tslearn.clustering import TimeSeriesKMeans
#       2 model = TimeSeriesKMeans(n_clusters=3, metric="dtw", max_iter=10)
# ----> 3 model.fit(cdf)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tslearn\clustering\kmeans.py:741, in TimeSeriesKMeans.fit(self, X, y)
#     729 def fit(self, X, y=None):
#     730     """Compute k-means clustering.
#     731
#     732     Parameters
#    (...)
#     738         Ignored
#     739     """
# --> 741     X = check_array(X, allow_nd=True, force_all_finite='allow-nan')
#     743     if hasattr(self.init, '__array__'):
#     744         X = check_dims(X, X_fit_dims=self.init.shape,
#     745                        extend=True,
#     746                        check_n_features_only=(self.metric != "euclidean"))
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      61 extra_args = len(args) - len(all_args)
#      62 if extra_args <= 0:
# ---> 63     return f(*args, **kwargs)
#      65 # extra_args > 0
#      66 args_msg = ['{}={}'.format(name, arg)
#      67             for name, arg in zip(kwonly_args[:extra_args],
#      68                                  args[-extra_args:])]
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:616, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614         array = array.astype(dtype, casting="unsafe", copy=False)
#     615     else:
# --> 616         array = np.asarray(array, order=order, dtype=dtype)
#     617 except ComplexWarning as complex_warning:
#     618     raise ValueError("Complex data not supported\n"
#     619                      "{}\n".format(array)) from complex_warning
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2069, in NDFrame.__array__(self, dtype)
#    2068 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2069     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Beaver Dam'

# %%
cdf.pivot(index="lake_name", columns=["mc_ppb", "do_mg_l"],values="mc_ppb")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [64], line 1
# ----> 1 cdf.pivot(index="lake_name", columns=["mc_ppb", "do_mg_l"],values="mc_ppb")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8557, in DataFrame.pivot(self, index, columns, values)
#    8551 @Substitution("")
#    8552 @Appender(_shared_docs["pivot"])
#    8553 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])
#    8554 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    8555     from pandas.core.reshape.pivot import pivot
# -> 8557     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:528, in pivot(data, index, columns, values)
#     524         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     525 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     526 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     527 # "Hashable"
# --> 528 return indexed.unstack(columns_listlike)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4458, in Series.unstack(self, level, fill_value)
#    4415 """
#    4416 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4417
#    (...)
#    4454 b    2    4
#    4455 """
#    4456 from pandas.core.reshape.reshape import unstack
# -> 4458 return unstack(self, level, fill_value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:467, in unstack(obj, level, fill_value)
#     463 if isinstance(level, (tuple, list)):
#     464     if len(level) != 1:
#     465         # _unstack_multiple only handles MultiIndexes,
#     466         # and isn't needed for a single level
# --> 467         return _unstack_multiple(obj, level, fill_value=fill_value)
#     468     else:
#     469         level = level[0]
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:418, in _unstack_multiple(data, clocs, fill_value)
#     415 dummy = data.copy()
#     416 dummy.index = dummy_index
# --> 418 unstacked = dummy.unstack("__placeholder__", fill_value=fill_value)
#     419 new_levels = clevels
#     420 new_names = cnames
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4458, in Series.unstack(self, level, fill_value)
#    4415 """
#    4416 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4417
#    (...)
#    4454 b    2    4
#    4455 """
#    4456 from pandas.core.reshape.reshape import unstack
# -> 4458 return unstack(self, level, fill_value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:490, in unstack(obj, level, fill_value)
#     488 if is_1d_only_ea_dtype(obj.dtype):
#     489     return _unstack_extension_series(obj, level, fill_value)
# --> 490 unstacker = _Unstacker(
#     491     obj.index, level=level, constructor=obj._constructor_expanddim
#     492 )
#     493 return unstacker.get_result(
#     494     obj._values, value_columns=None, fill_value=fill_value
#     495 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:138, in _Unstacker.__init__(self, index, level, constructor)
#     130 if num_cells > np.iinfo(np.int32).max:
#     131     warnings.warn(
#     132         f"The following operation may generate {num_cells} cells "
#     133         f"in the resulting pandas object.",
#     134         PerformanceWarning,
#     135         stacklevel=find_stack_level(inspect.currentframe()),
#     136     )
# --> 138 self._make_selectors()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:190, in _Unstacker._make_selectors(self)
#     187 mask.put(selector, True)
#     189 if mask.sum() < len(self.index):
# --> 190     raise ValueError("Index contains duplicate entries, cannot reshape")
#     192 self.group_index = comp_index
#     193 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape
