# %%
import pandas as pd
import numpy as np

# %%
from skimpy import clean_columns

# %%
df = pd.read_csv("LakeData.csv", low_memory = False)

# %% [markdown]
# # Clean the Data

# %%
list(df.columns)
# Out:
# ['Lake Name',
#  'Site type',
#  'ID #',
#  'Date',
#  'Time',
#  'PW',
#  'W',
#  'TotalDepth(m)',
#  'SecchiDepth',
#  'Depth(m)',
#  'Epi/Hypo',
#  'WaterTemp(CelS)',
#  'DO(% sat)',
#  'DO(mg/l)',
#  'pH',
#  'Con (mS/cm)',
#  'MC ID',
#  'AC ID',
#  'Nutrient ID',
#  'Layer',
#  'AT (°C)',
#  'Bar P (mbar)',
#  'Alt (m)',
#  'Max WS (m/h)',
#  'Avg WS (m/h)',
#  'Wind Direction',
#  'Chloro 1 Fluorosense',
#  'Chloro  2 Fluorosense',
#  'Phyco 1  Fluorosense',
#  'Phyco 2 Fluorosense',
#  'MC (ppb)',
#  'NH3',
#  'Cl',
#  'SO4',
#  'NO2',
#  'NO3',
#  'SiO2',
#  'SRP',
#  'TP',
#  'TKN',
#  'TN',
#  'COND',
#  'SS',
#  'F',
#  'Notes',
#  'Quanta #',
#  'Weather Meter #',
#  'Fluorometer #',
#  'Aquafluor #',
#  'Van Dorn #',
#  'Unnamed: 50',
#  'Unnamed: 51']

# %%
clean_df = clean_columns(df)
c_df = clean_df.drop(['site_type','mc_id', 'ac_id', 'pw', 'w', 'epi_hypo', 'notes'], axis = 1).dropna(how = "all")
c_df.head()
# Out:
# 52 column names have been cleaned
#     lake_name       id_#       date   time  total_depth_m secchi_depth  \
# 0  Beaver Dam  21221BEA2   8/9/2021  15:40           18.5          2.5
# 1  Beaver Dam  18190BEA2   7/9/2018  15:00           18.0          3.0
# 2  Beaver Dam  18204BEA2  7/23/2018  15:15           19.0          5.8
# 3  Beaver Dam  18211BEA2  7/31/2018  15:00           18.6          4.4
# 4  Beaver Dam  18218BEA2   8/6/2018  14:45           18.8          4.4
#
#    depth_m  water_temp_cel_s  do_%_sat  do_mg_l  ...  cond  ss   f quanta_#  \
# 0      0.0             26.90     113.4     9.05  ...   NaN NaN NaN      NaN
# 1      0.0             28.83     115.0     8.75  ...   NaN NaN NaN      NaN
# 2      0.0             25.21      88.7     7.27  ...   NaN NaN NaN      NaN
# 3      0.0             25.10     103.3     8.55  ...   NaN NaN NaN      NaN
# 4      0.0             28.77     120.2     9.30  ...   NaN NaN NaN      NaN
#
#    weather_meter_#  fluorometer_#  aquafluor_#  van_dorn_# unnamed_50  \
# 0              NaN            NaN          NaN         NaN        NaN
# 1              NaN            NaN          NaN         NaN        NaN
# 2              NaN            NaN          NaN         NaN        NaN
# 3              NaN            NaN          NaN         NaN        NaN
# 4              NaN            NaN          NaN         NaN        NaN
#
#   unnamed_51
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 45 columns]

# %%
c_df
# Out:
#         lake_name       id_#       date   time  total_depth_m secchi_depth  \
# 0      Beaver Dam  21221BEA2   8/9/2021  15:40           18.5          2.5
# 1      Beaver Dam  18190BEA2   7/9/2018  15:00           18.0          3.0
# 2      Beaver Dam  18204BEA2  7/23/2018  15:15           19.0          5.8
# 3      Beaver Dam  18211BEA2  7/31/2018  15:00           18.6          4.4
# 4      Beaver Dam  18218BEA2   8/6/2018  14:45           18.8          4.4
# ...           ...        ...        ...    ...            ...          ...
# 22764  Tippecanoe  21160TIP2   6/9/2021   9:41           37.4         13.4
# 22765  Tippecanoe  21195TIP2  7/14/2021  11:11           37.8          6.4
# 22766  Tippecanoe  21202TIP2  7/21/2021  11:00           37.8          8.0
# 22767  Tippecanoe  21209TIP2  7/28/2021  11:25           38.4          8.5
# 24219  Beaver Dam  16253BEA2   9/9/2016  13:37           18.4          4.6
#
#        depth_m  water_temp_cel_s  do_%_sat  do_mg_l  ...  cond  ss   f  \
# 0          0.0             26.90     113.4     9.05  ...   NaN NaN NaN
# 1          0.0             28.83     115.0     8.75  ...   NaN NaN NaN
# 2          0.0             25.21      88.7     7.27  ...   NaN NaN NaN
# 3          0.0             25.10     103.3     8.55  ...   NaN NaN NaN
# 4          0.0             28.77     120.2     9.30  ...   NaN NaN NaN
# ...        ...               ...       ...      ...  ...   ...  ..  ..
# 22764     36.0              5.40       3.1     0.39  ...   NaN NaN NaN
# 22765     36.0              5.50      10.6     1.32  ...   NaN NaN NaN
# 22766     36.0              5.50       4.6     0.58  ...   NaN NaN NaN
# 22767     36.0              5.50       5.6     0.69  ...   NaN NaN NaN
# 24219      NaN               NaN       NaN      NaN  ...   NaN NaN NaN
#
#       quanta_#  weather_meter_#  fluorometer_#  aquafluor_#  van_dorn_#  \
# 0          NaN              NaN            NaN          NaN         NaN
# 1          NaN              NaN            NaN          NaN         NaN
# 2          NaN              NaN            NaN          NaN         NaN
# 3          NaN              NaN            NaN          NaN         NaN
# 4          NaN              NaN            NaN          NaN         NaN
# ...        ...              ...            ...          ...         ...
# 22764      NaN              NaN            NaN          NaN         NaN
# 22765      NaN              NaN            NaN          NaN         NaN
# 22766      NaN              NaN            NaN          NaN         NaN
# 22767      NaN              NaN            NaN          NaN         NaN
# 24219      NaN              NaN            NaN          NaN         NaN
#
#       unnamed_50 unnamed_51
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# ...          ...        ...
# 22764        NaN        NaN
# 22765        NaN        NaN
# 22766        NaN        NaN
# 22767        NaN        NaN
# 24219        NaN        NaN
#
# [22769 rows x 45 columns]

# %%
', '.join(list(clean_df.columns))
# Out:
# 'lake_name, site_type, id_#, date, time, pw, w, total_depth_m, secchi_depth, depth_m, epi_hypo, water_temp_cel_s, do_%_sat, do_mg_l, p_h, con_m_s_cm, mc_id, ac_id, nutrient_id, layer, at_c, bar_p_mbar, alt_m, max_ws_m_h, avg_ws_m_h, wind_direction, chloro_1_fluorosense, chloro_2_fluorosense, phyco_1_fluorosense, phyco_2_fluorosense, mc_ppb, nh_3, cl, so_4, no_2, no_3, si_o_2, srp, tp, tkn, tn, cond, ss, f, notes, quanta_#, weather_meter_#, fluorometer_#, aquafluor_#, van_dorn_#, unnamed_50, unnamed_51'

# %% [markdown]
# ## Plot data and look for relationships

# %%
import matplotlib.pyplot as plt
import pylab as pl
# %matplotlib inline

# %%
cdf = clean_df[["do_mg_l", "mc_ppb", "water_temp_cel_s"]]
cdf.head(9)
# Out:
#    do_mg_l  mc_ppb  water_temp_cel_s
# 0     9.05     NaN             26.90
# 1     8.75   0.075             28.83
# 2     7.27   0.075             25.21
# 3     8.55   0.075             25.10
# 4     9.30   0.075             28.77
# 5    13.83   0.075             22.40
# 6    12.27   0.075             25.40
# 7    10.82   0.075             23.70
# 8     8.15   0.075             26.30

# %%
viz = cdf[["do_mg_l", "mc_ppb", "water_temp_cel_s"]]
viz.hist()
plt.show()

# %%
plt.scatter(cdf.do_mg_l, cdf.mc_ppb,  color='blue')
plt.xlabel("do_mg_l")
plt.ylabel("mc_ppb")
plt.show()

# %%
plt.scatter(cdf.water_temp_cel_s, cdf.mc_ppb,  color='blue')
plt.xlabel("water_temp_cel_s")
plt.ylabel("mc_ppb")
plt.show()

# %%
clean_df_lin = cdf.dropna()
clean_df_lin

msk = np.random.rand(len(clean_df_lin)) < 0.8
train = clean_df_lin[msk]
test = clean_df_lin[~msk]

# %% [markdown]
# ## Single Linear Regression

# %% [markdown]
# ### Relationship Between Dissolved Oxygen and Microcystin

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['do_mg_l']])
train_y = np.asanyarray(train[['mc_ppb']])
regr.fit(train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[0.03713026]]
# Intercept:  [0.122413]

# %%
plt.scatter(train.do_mg_l, train.mc_ppb,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Dissolved Oxygen (mg/l)")
plt.ylabel("Microcystin (ppb)")
# Out:
# Text(0, 0.5, 'Microcystin (ppb)')

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(test[["do_mg_l"]])
test_y = np.asanyarray(test[['mc_ppb']])
test_y_ = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y , test_y_) )
# Out:
# Mean absolute error: 0.54
# Residual sum of squares (MSE): 1.21
# R2-score: -0.02

# %% [markdown]
# ### Relationship between Water Temperature and Microcystin

# %%
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['water_temp_cel_s']])
train_y = np.asanyarray(train[['mc_ppb']])
regr.fit(train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[0.00857484]]
# Intercept:  [0.23632006]

# %%
plt.scatter(train.do_mg_l, train.mc_ppb,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Water Temperature (Cel.)")
plt.ylabel("Microcystin (ppb)")
# Out:
# Text(0, 0.5, 'Microcystin (ppb)')

# %%
test_x = np.asanyarray(test[["water_temp_cel_s"]])
test_y = np.asanyarray(test[['mc_ppb']])
test_y_ = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y , test_y_) )
# Out:
# Mean absolute error: 0.53
# Residual sum of squares (MSE): 1.18
# R2-score: 0.00

# %% [markdown]
# ### For both models, the R^2 score was 0, meaning the model proves to be of little use

# %% [markdown]
# ## Multiple Linear Regression

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['do_mg_l','water_temp_cel_s']])
y = np.asanyarray(train[['mc_ppb']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [[0.04028494 0.01161422]]

# %%
y_hat= regr.predict(test[['do_mg_l','water_temp_cel_s']])
x = np.asanyarray(test[['do_mg_l','water_temp_cel_s']])
y = np.asanyarray(test[['mc_ppb']])
print("Residual sum of squares: %.2f"
      % np.mean((y_hat - y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Residual sum of squares: 1.20
# Variance score: -0.02

# %% [markdown]
# Best possible score is 1.0, so this did not work well

# %% [markdown]
# ## K Means Clustering

# %%
import random 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 
from sklearn.datasets import make_blobs 
# %matplotlib inline

def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %%
clean_df_lin.head(5)
# Out:
#    do_mg_l  mc_ppb  water_temp_cel_s
# 1     8.75   0.075             28.83
# 2     7.27   0.075             25.21
# 3     8.55   0.075             25.10
# 4     9.30   0.075             28.77
# 5    13.83   0.075             22.40

# %%
from sklearn.preprocessing import StandardScaler
X = clean_df_lin.values[:,1:]
X = np.nan_to_num(X)
Clus_dataSet = StandardScaler().fit_transform(X)
Clus_dataSet
# Out:
# array([[-3.47614335e-01,  1.28200623e+00],
#        [-3.47614335e-01,  3.75942036e-02],
#        [-3.47614335e-01, -2.19421422e-04],
#        ...,
#        [-3.47614335e-01, -2.40851580e-01],
#        [-3.47614335e-01,  8.52305942e-01],
#        [ 1.40078828e-01, -5.15859762e-01]])

# %%
clusterNum = 5
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(X)
labels = k_means.labels_
print(labels)
# Out:
# [3 0 0 ... 0 3 0]

# %%
clean_df_lin["Clus_km"] = labels
clean_df_lin.head(5)
# Out:
#    do_mg_l  mc_ppb  water_temp_cel_s  Clus_km
# 1     8.75   0.075             28.83        3
# 2     7.27   0.075             25.21        0
# 3     8.55   0.075             25.10        0
# 4     9.30   0.075             28.77        3
# 5    13.83   0.075             22.40        1

# %%
clean_df_lin.groupby('Clus_km').mean()
# Out:
#           do_mg_l    mc_ppb  water_temp_cel_s
# Clus_km
# 0        8.778462  0.303775         25.266844
# 1        9.346912  0.271296         21.859193
# 2        9.835926  0.115926         14.904444
# 3        8.674951  0.296853         27.831225
# 4        8.657857  5.257000         25.118810

# %%
area = np.pi * ( X[:, 1])**2  
plt.scatter(X[:, 0], X[:, 1], s=area, c=labels.astype(np.float), alpha=0.5)
plt.xlabel('do_mg_l', fontsize=18)
plt.ylabel('mc_ppb', fontsize=16)

plt.show()

# %%
area = np.pi * ( X[:, 1])**2  
plt.scatter(X[:, 0], X[:, 1], s=area, c=labels.astype(np.float), alpha=0.5)
plt.xlabel('water_temp_cel_s', fontsize=18)
plt.ylabel('mc_ppb', fontsize=16)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure(1, figsize=(8, 6))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

plt.cla()
# plt.ylabel('Age', fontsize=18)
# plt.xlabel('Income', fontsize=16)
# plt.zlabel('Education', fontsize=16)
ax.set_xlabel('water_temp_cel_s')
ax.set_ylabel('do_mg_l')
ax.set_zlabel('mc_ppb')

ax.scatter(X[:, 1], X[:, 0], X[:, 1], c= labels.astype(np.float))

# %% [markdown]
# ### Add more variables to K-means

# %%
clean_df_k = clean_df[["do_mg_l", "mc_ppb", "water_temp_cel_s", "p_h"]].dropna()
clean_df_k.head(5)
# Out:
#    do_mg_l  mc_ppb  water_temp_cel_s   p_h
# 1     8.75   0.075             28.83  8.84
# 2     7.27   0.075             25.21  9.13
# 3     8.55   0.075             25.10  8.42
# 4     9.30   0.075             28.77  8.53
# 5    13.83   0.075             22.40  9.14

# %%
from sklearn.preprocessing import StandardScaler
X = clean_df_k.values[:,1:]
X = np.nan_to_num(X)
Clus_dataSet = StandardScaler().fit_transform(X)
Clus_dataSet
# Out:
# array([[-0.34506685,  1.31697339,  0.37541048],
#        [-0.34506685,  0.03743086,  0.52283493],
#        [-0.34506685, -0.00145026,  0.16189921],
#        ...,
#        [-0.34506685, -0.24887561, -0.1431169 ],
#        [-0.34506685,  0.87514241,  0.21781883],
#        [ 0.13234861, -0.53164744,  0.05005997]])

# %%
clusterNum = 5
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(X)
labels = k_means.labels_
print(labels)
# Out:
# [0 1 1 ... 1 0 1]

# %%
clean_df_k["Clus_km"] = labels
clean_df_k.head(5)
# Out:
#    do_mg_l  mc_ppb  water_temp_cel_s   p_h  Clus_km
# 1     8.75   0.075             28.83  8.84        0
# 2     7.27   0.075             25.21  9.13        1
# 3     8.55   0.075             25.10  8.42        1
# 4     9.30   0.075             28.77  8.53        0
# 5    13.83   0.075             22.40  9.14        1

# %%
clean_df_k.groupby('Clus_km').mean()
# Out:
#           do_mg_l    mc_ppb  water_temp_cel_s       p_h
# Clus_km
# 0        8.671304  0.298732         27.170643  8.667321
# 1        9.035164  0.302588         23.702009  8.495820
# 2        8.908429  0.350314         26.155714  0.429100
# 3        8.695250  5.349575         25.164000  8.795500
# 4        9.611132  0.169425         19.130755  8.325189

# %%
area = np.pi * ( X[:, 1])**2  
plt.scatter(X[:, 0], X[:, 1], s=area, c=labels.astype(np.float), alpha=0.5)
plt.xlabel('p_h', fontsize=18)
plt.ylabel('mc_ppb', fontsize=16)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure(1, figsize=(8, 6))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

plt.cla()
# plt.ylabel('Age', fontsize=18)
# plt.xlabel('Income', fontsize=16)
# plt.zlabel('Education', fontsize=16)
ax.set_xlabel('p_h')
ax.set_ylabel('do_mg_l')
ax.set_zlabel('mc_ppb')

ax.scatter(X[:, 1], X[:, 0], X[:, 1], c= labels.astype(np.float))

# %% [markdown]
# ## Hierarchical Clustering

# %%
import numpy as np 
import pandas as pd
from scipy import ndimage 
from scipy.cluster import hierarchy 
from scipy.spatial import distance_matrix 
from matplotlib import pyplot as plt 
from sklearn import manifold, datasets 
from sklearn.cluster import AgglomerativeClustering 
from sklearn.datasets import make_blobs 
# %matplotlib inline

# %%
pdf = clean_df[["lake_name","do_mg_l", "mc_ppb", "water_temp_cel_s", "p_h"]].dropna()
pdf.head(5)
# Out:
#     lake_name  do_mg_l  mc_ppb  water_temp_cel_s   p_h
# 1  Beaver Dam     8.75   0.075             28.83  8.84
# 2  Beaver Dam     7.27   0.075             25.21  9.13
# 3  Beaver Dam     8.55   0.075             25.10  8.42
# 4  Beaver Dam     9.30   0.075             28.77  8.53
# 5  Beaver Dam    13.83   0.075             22.40  9.14

# %%
featureset = clean_df[["do_mg_l", "mc_ppb", "water_temp_cel_s", "p_h"]].dropna()
featureset.head(5)
# Out:
#    do_mg_l  mc_ppb  water_temp_cel_s   p_h
# 1     8.75   0.075             28.83  8.84
# 2     7.27   0.075             25.21  9.13
# 3     8.55   0.075             25.10  8.42
# 4     9.30   0.075             28.77  8.53
# 5    13.83   0.075             22.40  9.14

# %%
from sklearn.preprocessing import MinMaxScaler
x = featureset.values #returns a numpy array
min_max_scaler = MinMaxScaler()
feature_mtx = min_max_scaler.fit_transform(x)
feature_mtx [0:5]
# Out:
# array([[0.34040996, 0.        , 0.88666667, 0.74446189],
#        [0.23206442, 0.        , 0.77174603, 0.76975406],
#        [0.32576867, 0.        , 0.76825397, 0.70783185],
#        [0.3806735 , 0.        , 0.8847619 , 0.71742543],
#        [0.71229868, 0.        , 0.68253968, 0.7706262 ]])

# %%
import scipy
leng = feature_mtx.shape[0]
D = scipy.zeros([leng,leng])
for i in range(leng):
    for j in range(leng):
        D[i,j] = scipy.spatial.distance.euclidean(feature_mtx[i], feature_mtx[j])
D
# Out:
# array([[0.        , 0.15995375, 0.12481063, ..., 0.18616288, 0.06969348,
#         0.19889444],
#        [0.15995375, 0.        , 0.1123701 , ..., 0.11972468, 0.18339824,
#         0.10454444],
#        [0.12481063, 0.1123701 , 0.        , ..., 0.08926078, 0.1026425 ,
#         0.09579151],
#        ...,
#        [0.18616288, 0.11972468, 0.08926078, ..., 0.        , 0.17881027,
#         0.05517708],
#        [0.06969348, 0.18339824, 0.1026425 , ..., 0.17881027, 0.        ,
#         0.19241026],
#        [0.19889444, 0.10454444, 0.09579151, ..., 0.05517708, 0.19241026,
#         0.        ]])

# %%
import pylab
import scipy.cluster.hierarchy
Z = hierarchy.linkage(D, 'complete')

# %%
from scipy.cluster.hierarchy import fcluster
max_d = 3
clusters = fcluster(Z, max_d, criterion='distance')
clusters
# Out:
# array([ 8, 11, 14, ..., 16,  7, 16], dtype=int32)

# %%
from scipy.cluster.hierarchy import fcluster
k = 5
clusters = fcluster(Z, k, criterion='maxclust')
clusters
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=int32)

# %%
fig = pylab.figure(figsize=(18,50))
def llf(id):
    return (pdf['lake_name'][id])
    
dendro = hierarchy.dendrogram(Z, leaf_rotation=0, leaf_font_size =12, orientation = 'right')

# %% [markdown]
# ### One to potentially come back to

# %% [markdown]
# ## Clustering with SciKitLearn

# %%
from sklearn.metrics.pairwise import euclidean_distances
dist_matrix = euclidean_distances(feature_mtx,feature_mtx) 
print(dist_matrix)
# Out:
# [[0.         0.15995375 0.12481063 ... 0.18616288 0.06969348 0.19889444]
#  [0.15995375 0.         0.1123701  ... 0.11972468 0.18339824 0.10454444]
#  [0.12481063 0.1123701  0.         ... 0.08926078 0.1026425  0.09579151]
#  ...
#  [0.18616288 0.11972468 0.08926078 ... 0.         0.17881027 0.05517708]
#  [0.06969348 0.18339824 0.1026425  ... 0.17881027 0.         0.19241026]
#  [0.19889444 0.10454444 0.09579151 ... 0.05517708 0.19241026 0.        ]]

# %%
Z_using_dist_matrix = hierarchy.linkage(dist_matrix, 'complete')

# %%
agglom = AgglomerativeClustering(n_clusters = 6, linkage = 'complete')
agglom.fit(dist_matrix)

agglom.labels_
# Out:
# array([4, 4, 4, ..., 4, 4, 4], dtype=int64)

# %%
pdf['cluster_'] = agglom.labels_
pdf.head()
# Out:
#     lake_name  do_mg_l  mc_ppb  water_temp_cel_s   p_h  cluster_
# 1  Beaver Dam     8.75   0.075             28.83  8.84         4
# 2  Beaver Dam     7.27   0.075             25.21  9.13         4
# 3  Beaver Dam     8.55   0.075             25.10  8.42         4
# 4  Beaver Dam     9.30   0.075             28.77  8.53         4
# 5  Beaver Dam    13.83   0.075             22.40  9.14         3

# %%
import matplotlib.cm as cm
n_clusters = max(agglom.labels_)+1
colors = cm.rainbow(np.linspace(0, 1, n_clusters))
cluster_labels = list(range(0, n_clusters))

# Create a figure of size 6 inches by 4 inches.
plt.figure(figsize=(16,14))

for color, label in zip(colors, cluster_labels):
    subset = pdf[pdf.cluster_ == label]
    for i in subset.index:
            plt.text(subset.do_mg_l[i], subset.mc_ppb[i],str(subset['lake_name'][i]), rotation=25) 
    plt.scatter(subset.do_mg_l, subset.mc_ppb, c=color, label='cluster'+str(label),alpha=0.5)
#    plt.scatter(subset.horsepow, subset.mpg)
plt.legend()
plt.title('Clusters')
plt.xlabel('do_mg_l')
plt.ylabel('mc_ppb')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# Text(0, 0.5, 'mc_ppb')

# %% [markdown]
# ### Want to look into splitting up by years

# %%
from datetime import datetime
clean_df['date'] = clean_df.to_datetime(clean_df['date'], format='%m-%d-%Y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [103], line 2
#       1 from datetime import datetime
# ----> 2 clean_df['date'] = clean_df.to_datetime(clean_df['date'], format='%m-%d-%Y')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_datetime'
